# %%
import pandas as P

# %%
D = P.read_csv("Car_Data_5.csv")

# %%
print(D.columns)
# Out:
# Index(['Unnamed: 0.3', 'Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0',
#        'City MPG', 'Class', 'Combination MPG', 'Cylinders', 'Displacement',
#        'Drive', 'Fuel Type', 'Highway MPG', 'Make', 'Model', 'Transmission',
#        'Year', 'Age', 'Displacement_Group', 'MPG_Efficiency_City',
#        'MPG_Efficiency_Highway', 'MPG_Efficiency_Combined'],
#       dtype='object')

# %%
import matplotlib.pyplot as PLOT

# %%
City_MPG = D["City MPG"]

# %%
PLOT.hist(City_MPG)
PLOT.title("City MPG Distribution")
PLOT.xlabel("MPG")
PLOT.ylabel("Frequency")
PLOT.show()
